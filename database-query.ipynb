# %%
# import 
import numpy as np
import pandas as pd
import datetime as dt
import sqlalchemy as db
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import session
from sqlalchemy import create_engine
from config import db_password

# %%
# connect to remote db
db_string = f"postgresql://postgres:{db_password}@database-3.csjzcnuh5mqe.us-east-2.rds.amazonaws.com:5432/Final Project"

# %%
# define the engine and connection
engine = db.create_engine(db_string)
conn = engine.connect()

# %%
# query the db - cout fires by city
results = 'SELECT count (city) as "fire-count", city FROM ca_fire GROUp BY city'

# %%
ca_fire_df= pd.read_sql(results, conn)
ca_fire_df
# Out:
#      fire-count           city
# 0            10        Hanford
# 1           505  Granada Hills
# 2            20     Coarsegold
# 3             3       Redlands
# 4           277       Glendale
# ..          ...            ...
# 671           1         Mojave
# 672         104   Porter Ranch
# 673           2      Annapolis
# 674          57         Delano
# 675           2      Mira Loma
#
# [676 rows x 2 columns]

# %%
ca_housing =  "SELECT city, jan, feb, mar, apr, may,\
    jun, jul, aug, sep, oct, nov, dec\
    FROM ca_housing"

# %%
ca_housing_df= pd.read_sql(ca_housing, conn)
ca_housing_df
# Out:
#                 city     jan     feb     mar     apr     may     jun     jul  \
# 0        Los Angeles  431284  431834  431883  434223  437189  439420  437700
# 1        Los Angeles  493023  491204  489511  489494  489850  491273  489745
# 2            Norwalk  487572  485517  484164  484345  485361  486121  484453
# 3               Bell  451985  451959  452378  452891  452835  453393  452322
# 4            Fontana  350245  351116  352676  354228  356071  357008  356722
# ...              ...     ...     ...     ...     ...     ...     ...     ...
# 1394    Soda Springs  557324  555721  555257  561994  560237  557938  552008
# 1395          Sonoma  609324  603717  603966  604240  610094  615195  622122
# 1396      Myers Flat  402804  393794  384356  385227  384046  384725  378135
# 1397  Round Mountain  219284  218838  218146  217844  220667  227675  232549
# 1398    Twin Bridges  255961  256672  258241  257213  260170  260550  263673
#
#          aug     sep     oct     nov     dec
# ...

# %%
jan = ca_housing_df.groupby(["city"])["jan"].median()
df_jan = pd.DataFrame(jan)

# %%
feb = ca_housing_df.groupby(["city"])["feb"].median()
df_feb = pd.DataFrame(feb)

# %%
mar = ca_housing_df.groupby(["city"])["mar"].median()
df_mar = pd.DataFrame(mar)

# %%
apr = ca_housing_df.groupby(["city"])["apr"].median()
df_apr = pd.DataFrame(apr)

# %%
may = ca_housing_df.groupby(["city"])["may"].median()
df_may = pd.DataFrame(may)

# %%
jun = ca_housing_df.groupby(["city"])["jun"].median()
df_jun = pd.DataFrame(jun)

# %%
jul = ca_housing_df.groupby(["city"])["jul"].median()
df_jul = pd.DataFrame(jul)

# %%
aug = ca_housing_df.groupby(["city"])["aug"].median()
df_aug = pd.DataFrame(aug)

# %%
sep = ca_housing_df.groupby(["city"])["sep"].median()
df_sep = pd.DataFrame(sep)

# %%
octo = ca_housing_df.groupby(["city"])["oct"].median()
df_oct = pd.DataFrame(octo)

# %%
nov = ca_housing_df.groupby(["city"])["nov"].median()
df_nov = pd.DataFrame(nov)

# %%
dec = ca_housing_df.groupby(["city"])["dec"].median()
df_dec = pd.DataFrame(dec)

# %%
ca_houz = pd.concat([df_jan,df_feb, df_mar,df_apr,df_may,df_jun,df_jul,df_aug,df_sep,df_oct,df_nov,df_dec], axis=1)
ca_houz
# Out:
#                    jan       feb       mar       apr       may       jun  \
# city
# Acampo        555749.0  557124.0  559033.0  558365.0  559425.0  560189.0
# Acton         604387.0  604697.0  605355.0  605615.0  607799.0  609758.0
# Adelanto      233445.0  234638.0  235892.0  236498.0  237585.0  237840.0
# Adin          152317.0  152542.0  152708.0  153201.0  153249.0  153371.0
# Agoura Hills  892446.0  888334.0  886704.0  883896.0  884138.0  885551.0
# ...                ...       ...       ...       ...       ...       ...
# Wrightwood    300918.0  300947.0  301443.0  301473.0  300854.0  300787.0
# Yorba Linda   868860.0  866031.5  864516.0  862516.5  862329.0  860852.5
# Yuba City     308058.0  308632.5  308799.0  309392.5  311117.5  312984.5
# Yucaipa       374727.0  375415.0  376162.0  376027.0  376771.0  377059.0
# Yucca Valley  216029.0  217773.0  219045.0  220398.0  222348.0  223739.0
#
#                    jul       aug       sep       oct       nov       dec
# city
# ...

# %%
# export ca_housing
ca_houz.to_csv('ca_housing_median.csv')

# %%
# loop through tbl
for result in results:
    print(result)

# %%
# give the SQL a variable - merge tbls with a join
sql = "SELECT \
    f.city, population, violentcrime, murder, rape, robbery, \
    aggassault, cr.propertycrime, burglary, theft, \
    vehicletheft, arson, acq, month, zipcode, metro, county, \
    jan, feb, mar, apr, may, jun, jul, aug, sep, oct, nov, dec \
    FROM ca_crime Cr \
    INNER JOIN ca_fire f ON cr.city = f.city \
    INNER JOIN ca_housing h ON h.city = f.city \
    Group on f.city "

# %%
# create df  with column headers
query_df= pd.read_sql(sql, conn)
query_df
# Out:
#             city  population  violentcrime  murder  rape  robbery  aggassault  \
# 0      San Diego     1441737          5215      50   561     1346        3258
# 1      San Diego     1441737          5215      50   561     1346        3258
# 2      San Diego     1441737          5215      50   561     1346        3258
# 3      San Diego     1441737          5215      50   561     1346        3258
# 4      San Diego     1441737          5215      50   561     1346        3258
# ...          ...         ...           ...     ...   ...      ...         ...
# 42154     Oakley       43014            51       0     7       17          27
# 42155     Oakley       43014            51       0     7       17          27
# 42156     Oakley       43014            51       0     7       17          27
# 42157     Oakley       43014            51       0     7       17          27
# 42158     Oakley       43014            51       0     7       17          27
#
# ...
